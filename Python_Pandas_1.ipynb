# %% [markdown]
# Exemplos iniciais:

# %%
#Biblioteca Pandas
import pandas as pd

# %%
#Biblioteca Numpy
import numpy as np

# %%
#Biblioteca de gráficos Matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# Série com temperaturas:

# %%
temperaturas = pd.Series([20,25,30,35,40])

temperaturas
# Out:
# 0    20
# 1    25
# 2    30
# 3    35
# 4    40
# dtype: int64

# %%
temperaturas
# Out:
# 0    20
# 1    25
# 2    30
# 3    35
# 4    40
# dtype: int64

# %% [markdown]
# Verificando o conteúdo:

# %%
temperaturas.values
# Out:
# array([20, 25, 30, 35, 40])

# %% [markdown]
# Verificando o índice usado:

# %%
temperaturas.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %% [markdown]
# Acrescentando as cidades:

# %%
temperaturas = pd.Series([20, 25, 30, 35, 32, 45],
index=["Itatiaia", "Petrópolis", "Teresópolis", "Niterói", "Friburgo", "Rio de Janeiro"])

temperaturas
# Out:
# Itatiaia          20
# Petrópolis        25
# Teresópolis       30
# Niterói           35
# Friburgo          32
# Rio de Janeiro    45
# dtype: int64

# %% [markdown]
# Verificando a temperatura de uma cidade:

# %%
temperaturas['Petrópolis']
# Out:
# 25

# %% [markdown]
# Exibindo a média de temperaturas:

# %%
print("Média:", temperaturas.mean())
# Out:
# Média: 28.666666666666668

# %% [markdown]
# Exibindo a mediana de temperaturas:

# %%
print("Mediana:", temperaturas.median())
# Out:
# Mediana: 31.0

# %% [markdown]
# Exibindo o desvio padrão:

# %%
print("Desvio padrão:", temperaturas.std())
# Out:
# Desvio padrão: 13.366625103842281

# %% [markdown]
# Resumo estatístico do dataset:

# %%
temperaturas.describe()
# Out:
# count     6.000000
# mean     31.166667
# std       8.612007
# min      20.000000
# 25%      26.250000
# 50%      31.000000
# 75%      34.250000
# max      45.000000
# dtype: float64

# %% [markdown]
# Dataframe:

# %%
df = pd.DataFrame({'municipio' : ["Petrópolis", "Itatiaia", "Teresópolis", "Niterói", "Rio de Janeiro"],
                   'populacao' : [306678,29996,185820,513584,6775561],
                   'clima' : ['tropical de altitude','subtropical','oceânico de altitude','tropical','tropical atlântico'],
                   'altitude': [838,1648,869,2,2],
                   'area': [795798,224957,770000,129.3,1200329],
                   'idh': [0.745,0.737,0.730,0.837,0.799]})
df
# Out:
#         municipio  populacao                 clima  altitude       area    idh
# 0      Petrópolis     306678  tropical de altitude       838   795798.0  0.745
# 1        Itatiaia      29996           subtropical      1648   224957.0  0.737
# 2     Teresópolis     185820  oceânico de altitude       869   770000.0  0.730
# 3         Niterói     513584              tropical         2      129.3  0.837
# 4  Rio de Janeiro    6775561    tropical atlântico         2  1200329.0  0.799
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['populacao'].plot(kind='hist', bins=20, title='populacao')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['altitude'].plot(kind='hist', bins=20, title='altitude')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['area'].plot(kind='hist', bins=20, title='area')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('municipio').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_5.groupby('clima').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='index', y='populacao', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='populacao', y='altitude', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='altitude', y='area', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9.plot(kind='scatter', x='area', y='idh', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['populacao']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('municipio')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='municipio', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('populacao')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['populacao']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('clima')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='clima', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('populacao')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['altitude']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('municipio')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='municipio', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('altitude')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['altitude']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_13.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('clima')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='clima', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('altitude')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_14['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['populacao'].plot(kind='line', figsize=(8, 4), title='populacao')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['altitude'].plot(kind='line', figsize=(8, 4), title='altitude')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['area'].plot(kind='line', figsize=(8, 4), title='area')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['clima'].value_counts()
#     for x_label, grp in _df_18.groupby('municipio')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('municipio')
# _ = plt.ylabel('clima')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_19['municipio'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_19, x='index', y='municipio', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_20['clima'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_20, x='index', y='clima', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_21['municipio'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_21, x='populacao', y='municipio', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_22['clima'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_22, x='populacao', y='clima', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# Verificando os tipos de dados:

# %%
df.dtypes
# Out:
# municipio     object
# populacao      int64
# clima         object
# altitude       int64
# area         float64
# idh          float64
# dtype: object

# %% [markdown]
# Nomes das colunas:

# %%
df.columns
# Out:
# Index(['municipio', 'populacao', 'clima', 'altitude', 'area', 'idh'], dtype='object')

# %% [markdown]
# Consultando os dados de uma coluna:

# %%
df['municipio']
# Out:
# 0        Petrópolis
# 1          Itatiaia
# 2       Teresópolis
# 3           Niterói
# 4    Rio de Janeiro
# Name: municipio, dtype: object

# %% [markdown]
# Ordenando por uma coluna:

# %%
df.sort_values(by = "municipio")
# Out:
#         municipio  populacao                 clima  altitude       area    idh
# 1        Itatiaia      29996           subtropical      1648   224957.0  0.737
# 3         Niterói     513584              tropical         2      129.3  0.837
# 0      Petrópolis     306678  tropical de altitude       838   795798.0  0.745
# 4  Rio de Janeiro    6775561    tropical atlântico         2  1200329.0  0.799
# 2     Teresópolis     185820  oceânico de altitude       869   770000.0  0.730

# %% [markdown]
# Estatística básica do dataframe:

# %%
df.describe()
# Out:
#           populacao     altitude          area       idh
# count  5.000000e+00     5.000000  5.000000e+00  5.000000
# mean   1.562328e+06   671.800000  5.982427e+05  0.769600
# std    2.919638e+06   692.232042  4.816945e+05  0.046484
# min    2.999600e+04     2.000000  1.293000e+02  0.730000
# 25%    1.858200e+05     2.000000  2.249570e+05  0.737000
# 50%    3.066780e+05   838.000000  7.700000e+05  0.745000
# 75%    5.135840e+05   869.000000  7.957980e+05  0.799000
# max    6.775561e+06  1648.000000  1.200329e+06  0.837000

# %% [markdown]
# Para consultar pelo valor de um índice:

# %%
df.loc[2]
# Out:
# municipio             Teresópolis
# populacao                  185820
# clima        oceânico de altitude
# altitude                      869
# area                     770000.0
# idh                          0.73
# Name: 2, dtype: object

# %% [markdown]
# Consultando por uma condição:

# %%
df[df["altitude"] > 500]
# Out:
#      municipio  populacao                 clima  altitude      area    idh
# 0   Petrópolis     306678  tropical de altitude       838  795798.0  0.745
# 1     Itatiaia      29996           subtropical      1648  224957.0  0.737
# 2  Teresópolis     185820  oceânico de altitude       869  770000.0  0.730

# %% [markdown]
# Condição composta:

# %%
df[(df["altitude"] > 500) & (df['idh'] > 0.7)]
# Out:
#      municipio  populacao                 clima  altitude      area    idh
# 0   Petrópolis     306678  tropical de altitude       838  795798.0  0.745
# 1     Itatiaia      29996           subtropical      1648  224957.0  0.737
# 2  Teresópolis     185820  oceânico de altitude       869  770000.0  0.730

# %% [markdown]
# Agora vamos alterar o valor de uma coluna. Primeiro verificamos o valor que vamos alterar:

# %%
df[df.clima == 'tropical de altitude']
# Out:
#     municipio  populacao                 clima  altitude      area    idh
# 0  Petrópolis     306678  tropical de altitude       838  795798.0  0.745

# %% [markdown]
# Efetuando o replace:

# %%
df['clima'] = df['clima'].replace(['tropical de altitude'],'Tropical de altitude')
df
# Out:
#         municipio  populacao                 clima  altitude       area    idh
# 0      Petrópolis     306678  Tropical de altitude       838   795798.0  0.745
# 1        Itatiaia      29996           subtropical      1648   224957.0  0.737
# 2     Teresópolis     185820  oceânico de altitude       869   770000.0  0.730
# 3         Niterói     513584              tropical         2      129.3  0.837
# 4  Rio de Janeiro    6775561    tropical atlântico         2  1200329.0  0.799

# %% [markdown]
# Exibindo a forma do conjunto de dados:

# %%
#nr de linhas e colunas
df.shape
# Out:
# (5, 6)

# %% [markdown]
# Exibindo todo o conjunto de dados:

# %%
print(df)
# Out:
#         municipio  populacao                 clima  altitude       area    idh
# 0      Petrópolis     306678  Tropical de altitude       838   795798.0  0.745
# 1        Itatiaia      29996           subtropical      1648   224957.0  0.737
# 2     Teresópolis     185820  oceânico de altitude       869   770000.0  0.730
# 3         Niterói     513584              tropical         2      129.3  0.837
# 4  Rio de Janeiro    6775561    tropical atlântico         2  1200329.0  0.799

# %% [markdown]
# Importando um arquivo .csv:

# %%
df2 = pd.read_csv("/content/sample_data/california_housing_test.csv")
df2
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 0         1537.0       606.0         6.6085            344700.0
# 1          809.0       277.0         3.5990            176500.0
# 2         1484.0       495.0         5.7934            270500.0
# 3           49.0        11.0         6.1359            330000.0
# 4          850.0       237.0         2.9375             81700.0
# ...          ...         ...            ...                 ...
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0
#
# [3000 rows x 9 columns]

# %%
df2.shape
# Out:
# (3000, 9)

# %% [markdown]
# Verificando não nulos:

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %% [markdown]
# Ou ainda:

# %%
df2.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %% [markdown]
# Para visualizar as 5 primeiras linhas:

# %%
df2.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %% [markdown]
# Ou definindo a quantidade de linhas a serem exibidas:

# %%
df2.head(n = 10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
# 6    -121.43     38.63                43.0       1009.0           225.0
# 7    -120.65     35.48                19.0       2310.0           471.0
# 8    -122.84     38.40                15.0       3080.0           617.0
# 9    -118.02     34.08                31.0       2402.0           632.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0
# 5       663.0       204.0         1.6635             67000.0
# 6       604.0       218.0         1.6641             67000.0
# 7      1341.0       441.0         3.2250            166900.0
# 8      1446.0       599.0         3.6696            194400.0
# 9      2830.0       603.0         2.3333            164200.0

# %% [markdown]
# Exibindo as 5 últimas linhas:

# %%
df2.tail()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %% [markdown]
# Totais de uma coluna:

# %%
df2["housing_median_age"].value_counts()
# Out:
# 52.0    173
# 35.0    118
# 36.0    115
# 16.0    107
# 34.0    102
# 17.0    100
# 32.0     91
# 37.0     88
# 26.0     88
# 25.0     86
# 33.0     85
# 15.0     77
# 19.0     76
# 18.0     76
# 30.0     76
# 24.0     75
# 29.0     75
# 27.0     74
# 38.0     64
# 20.0     63
# 21.0     61
# 22.0     60
# 28.0     58
# 14.0     57
# 31.0     57
# 41.0     56
# 43.0     56
# 39.0     55
# 23.0     53
# 44.0     51
# 45.0     51
# 42.0     51
# 40.0     43
# 46.0     41
# 11.0     41
# 12.0     41
# 13.0     41
# 5.0      39
# 48.0     34
# 10.0     30
# 4.0      28
# 9.0      27
# 6.0      25
# 8.0      25
# 47.0     22
# 49.0     21
# 7.0      20
# 50.0     16
# 3.0      12
# 51.0     11
# 2.0       6
# 1.0       2
# Name: housing_median_age, dtype: int64

# %% [markdown]
# Agrupando dados:

# %%
df2.groupby("latitude").sum()["total_rooms"].sort_values()
# Out:
# latitude
# 35.08        83.0
# 37.08        97.0
# 40.99       141.0
# 39.48       202.0
# 39.20       204.0
#            ...
# 34.12     77358.0
# 34.10     85202.0
# 34.02     88819.0
# 33.87     90262.0
# 34.11    102063.0
# Name: total_rooms, Length: 587, dtype: float64

# %% [markdown]
# Verificando valores nulos. Primeiramente, vamos criar outro dataframe a partir do df2:

# %%
df3 = df2.head()

# %%
df3.shape
# Out:
# (5, 9)

# %% [markdown]
# Retornando as linhas que não tem valores nulos:

# %%
df3.dropna()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %% [markdown]
# Verificando NaN

# %%
df3.isna()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0      False     False               False        False           False
# 1      False     False               False        False           False
# 2      False     False               False        False           False
# 3      False     False               False        False           False
# 4      False     False               False        False           False
#
#    population  households  median_income  median_house_value
# 0       False       False          False               False
# 1       False       False          False               False
# 2       False       False          False               False
# 3       False       False          False               False
# 4       False       False          False               False

# %% [markdown]
# Listando com uma condição composta:

# %%
df3.query('population > 800 and total_bedrooms > 100')
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 4       850.0       237.0         2.9375             81700.0

# %% [markdown]
# Histograma da média de idade:

# %%
df3["housing_median_age"].plot.hist()

# %%
df2["housing_median_age"].plot.hist()

# %% [markdown]
# Gráfico de pizza pela média de idade:

# %%
df3["housing_median_age"].value_counts().plot.pie()

# %%
df2.sample(frac=.1).plot.scatter(x='longitude', y='latitude')

# %%
df2.sample(frac=.1).plot.scatter(x='population', y='median_house_value')
